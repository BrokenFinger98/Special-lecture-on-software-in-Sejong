# %%
import tensorflow as tf

# %%
(train_images, train_labels), (test_images, test_labels)= tf.keras.datasets.mnist.load_data()

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(784,))) # 은닉층1
#model.add(tf.keras.layers.Dense(512, activation='relu')) # 은닉층2
model.add(tf.keras.layers.Dense(10, activation='sigmoid')) # 출력층

# %%
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer='rmsprop',
                loss='mse',
                metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 784))
train_images = train_images.astype('float32') / 255.0

# %%
test_images = test_images.reshape((10000, 784))
test_images = test_images.astype('float32') / 255.0

# %%
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.0160 - accuracy: 0.9160
# Epoch 2/5
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.0063 - accuracy: 0.9660
# Epoch 3/5
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.0044 - accuracy: 0.9774
# Epoch 4/5
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.0034 - accuracy: 0.9827
# Epoch 5/5
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.0027 - accuracy: 0.9865

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('테스트 정확도:', test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 테스트 정확도: 0.9794
