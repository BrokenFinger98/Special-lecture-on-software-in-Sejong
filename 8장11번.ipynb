# %%
import tensorflow as tf
from tensorflow import keras

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
train_images = train_images.reshape((60000, 784))
test_images = test_images.reshape((10000, 784))

# %%
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(784,)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=5, batch_size = 128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.5459 - accuracy: 0.8028
# Epoch 2/5
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3738 - accuracy: 0.8621
# Epoch 3/5
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3336 - accuracy: 0.8767
# Epoch 4/5
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3068 - accuracy: 0.8863
# Epoch 5/5
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.2886 - accuracy: 0.8925

# %%
test_loss_d, test_acc_d = model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(784,)))
model.add(tf.keras.layers.Dense(10, activation='sigmoid'))

# %%
model.compile(optimizer='adam',
              loss='mse',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=5, batch_size = 128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.0316 - accuracy: 0.7926
# Epoch 2/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0209 - accuracy: 0.8631
# Epoch 3/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0188 - accuracy: 0.8765
# Epoch 4/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.0174 - accuracy: 0.8860
# Epoch 5/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.0165 - accuracy: 0.8920

# %%
test_loss_m, test_acc_m = model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('DNN 정확도:', test_acc_d)
print('MLP 정확도:', test_acc_m)
# Out:
# DNN 정확도: 0.8746
# MLP 정확도: 0.8776
